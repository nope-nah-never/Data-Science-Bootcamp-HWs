# %% [markdown]
# Problem1

# %%
word = input("Enter a word: ")
vowels = ["a", "e", "i", "o", "u", "A", "E", "I", "O", "U"]
cnt=0
for s in word:
  if s in vowels:
    cnt+=1

print(cnt)
# Out:
# Enter a word: aslhdpuwiejA
# 5

# %% [markdown]
# Problem2

# %%
animals= ["tiger", "elephant","monkey", "zebra","panther"]
cap_animals=[]
for animal in animals:
  animal= animal.capitalize()
  cap_animals.append(animal)
print(cap_animals)
# Out:
# ['Tiger', 'Elephant', 'Monkey', 'Zebra', 'Panther']

# %% [markdown]
# Problem3

# %%
for i in range(1,21):
  decision = "odd"
  if i%2==0:
    decision="even"
  print(f"{i} : {decision}")
# Out:
# 1 : odd
# 2 : even
# 3 : odd
# 4 : even
# 5 : odd
# 6 : even
# 7 : odd
# 8 : even
# 9 : odd
# 10 : even
# 11 : odd
# 12 : even
# 13 : odd
# 14 : even
# 15 : odd
# 16 : even
# 17 : odd
# 18 : even
# 19 : odd
# 20 : even

# %% [markdown]
# Problem4

# %%
input_word= input("Input a word: ")
l=0
r=len(input_word)-1

while l<r:
  if input_word[l] != input_word[r]:
    print("Word is not a palindrome")
    break
  l+=1
  r-=1

if l>=r:
  print("Word is a palindrome")
# Out:
# Input a word: dada
# Word is not a palindrome

# %% [markdown]
# Problem5

# %%
def sum_of_integers(a,b):
  return int(a) + int(b)

a= input("Enter first number: ")
b= input("Enter second number: ")
sum_of_integers(a,b)
# Out:
# Enter first number: 34
# Enter second number: 90
# 124
